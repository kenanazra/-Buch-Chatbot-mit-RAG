# %% [markdown]
# # Chatbot über den Inhalt eines Buches mit RAG-Architektur
# Entwicklung eines KI-Systems, das über reine Textverarbeitung hinausgeht und tiefes inhaltliches Verständnis von literarischen Werken demonstriert

# %% [markdown]
# ## Import Bibliotheken

# %%
import os
import re
import warnings
from typing import List, Dict, Any, Optional

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.schema import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.chat_models import ChatOllama
from langchain_core.runnables import RunnablePassthrough, RunnableLambda

# Configuration and environment setup
warnings.filterwarnings('ignore')
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

# %% [markdown]
# ## Globale Konfigurationsparameter

# %%
# Global configuration
PDF_FILE = "Heidi.pdf"
CHUNKS_DB_DIR = "heidi_faiss_chunks"
CHAPTERS_DB_DIR = "heidi_faiss_chapters"
EMBEDDINGS_MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"

# %% [markdown]
# ## PDF-Verarbeitungsklasse

# %%
class PDFProcessor:

    
    def __init__(self, pdf_path: str):
        self.pdf_path = pdf_path
        self.embeddings = HuggingFaceEmbeddings(model_name=EMBEDDINGS_MODEL_NAME)
        self.llm = ChatOllama(model="llama3.2", temperature=0.2)
        
    # PDF-LADEFUNKTION 
    def load_pdf_document(self) -> List[Document]:

        if not os.path.exists(self.pdf_path):
            raise FileNotFoundError(f"PDF file not found: {self.pdf_path}")
        
        loader = PyPDFLoader(self.pdf_path)
        pages = loader.load()
        print(f"Loaded {len(pages)} pages from {self.pdf_path}")
        return pages
        
    # TEXTBEREINIGUNGSFUNKTION
    def clean_document_text(self, documents: List[Document]) -> List[Document]:

        cleaned_docs = []
        
        for doc in documents:
            text = doc.page_content
            # Entfernen Sie übermäßige Zeilenumbrüche und Leerzeichen
            text = re.sub(r'\n+', ' ', text)
            text = re.sub(r'\s+', ' ', text).strip()
            # Archivwasserzeichen entfernen
            text = re.sub(r'Full Text Archive\s*https://www\.fulltextarchive\.com', '', text)
            # Seitenzahlen entfernen
            text = re.sub(r'^\s*\d+\s*$', '', text)
            
            cleaned_docs.append(Document(page_content=text, metadata=doc.metadata))
        
        print(f"Cleaned {len(cleaned_docs)} documents")
        return cleaned_docs
        
    # TEXT-SEGMENTIERUNGSFUNKTION
    def chunk_documents(self, documents: List[Document], chunk_size: int = 800, chunk_overlap: int = 120) -> List[Document]:
 
        splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            separators=["\n\n", "\n", ".", "!", "?", ";", ",", " ", ""]
        )
        chunks = splitter.split_documents(documents)
        print(f"Created {len(chunks)} text chunks")
        return chunks

# %% [markdown]
# ## Kapitalextraktionsklasse

# %%
class ChapterExtractor:

    # RÖMISCHE ZAHLEN-KONVERTIERUNGSTABELLE 
    ROMAN_NUMERAL_MAP = {
        'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'VI': 6, 'VII': 7, 'VIII': 8, 
        'IX': 9, 'X': 10, 'XI': 11, 'XII': 12, 'XIII': 13, 'XIV': 14, 'XV': 15,
        'XVI': 16, 'XVII': 17, 'XVIII': 18, 'XIX': 19, 'XX': 20, 'XXI': 21, 
        'XXII': 22, 'XXIII': 23
    }
    
    def __init__(self):
         # REGEX-PATTERN FÜR KAPITELERKENNUNG
        self.chapter_pattern = re.compile(r'(^|\n)\s*CHAPTER\s+([IVXLCDM]+)\.(.*)?', re.IGNORECASE)

    # KAPITELEXTRAKTIONSFUNKTION
    def extract_chapters_from_text(self, full_text: str) -> List[Dict[str, Any]]:

        print("Extracting chapters from text...")
        
        matches = list(self.chapter_pattern.finditer(full_text))
        if not matches:
            print("No chapter markers found in text")
            return []
        
        chapters = []
        for i, match in enumerate(matches):
            start_pos = match.start()
            end_pos = matches[i + 1].start() if i + 1 < len(matches) else len(full_text)
            
            roman_numeral = match.group(2).upper()
            chapter_number = self.ROMAN_NUMERAL_MAP.get(roman_numeral, i + 1)
            title_suffix = (match.group(3) or "").strip()
            chapter_title = f"CHAPTER {roman_numeral}." + (f" {title_suffix}" if title_suffix else "")
            chapter_content = full_text[start_pos:end_pos].strip()
            
            chapter_data = {
                "number": chapter_number,
                "roman": roman_numeral,
                "title": chapter_title,
                "content": chapter_content,
                "start_pos": start_pos,
                "end_pos": end_pos
            }
            chapters.append(chapter_data)
            print(f"Found {chapter_title} at position {start_pos}")
        
        print(f"Successfully extracted {len(chapters)} chapters")
        return chapters

# %% [markdown]
# ## Vector-store-management-klasse

# %%
class VectorStoreManager:

    
    def __init__(self, embeddings):
        self.embeddings = embeddings
    # CHUNK-DATENBANK-MANAGEMENT
    def create_or_load_chunk_database(self, pdf_path: str, db_path: str) -> FAISS:

        if os.path.exists(db_path):
            print(f"Loading existing chunk database from {db_path}")
            return FAISS.load_local(db_path, self.embeddings, allow_dangerous_deserialization=True)
        
        print("Creating new chunk database...")
        processor = PDFProcessor(pdf_path)
        pages = processor.load_pdf_document()
        cleaned_pages = processor.clean_document_text(pages)
        chunks = processor.chunk_documents(cleaned_pages)
        
        vector_db = FAISS.from_documents(chunks, self.embeddings)
        vector_db.save_local(db_path)
        print(f"Chunk database saved to {db_path}")
        return vector_db

    # KAPITEL-DATENBANK-MANAGEMENT
    def create_or_load_chapter_database(self, pdf_path: str, db_path: str) -> FAISS:

        if os.path.exists(db_path):
            print(f"Loading existing chapter database from {db_path}")
            return FAISS.load_local(db_path, self.embeddings, allow_dangerous_deserialization=True)
        
        print("Creating new chapter database...")
        processor = PDFProcessor(pdf_path)
        pages = processor.load_pdf_document()
        full_text = "\n".join(page.page_content for page in pages)
        
        extractor = ChapterExtractor()
        chapters = extractor.extract_chapters_from_text(full_text)
        
        chapter_documents = []
        for chapter in chapters:
            # KAPITELTEXT-BEREINIGUNG
            content = re.sub(r'\n+', ' ', chapter['content'])
            content = re.sub(r'\s+', ' ', content).strip()
            # KAPITEL-FORMATIERUNG
            formatted_content = f"""
{'='*60}
CHAPTER {chapter['number']}: {chapter['title']}
{'='*60}

{content}
""".strip()

            doc = Document(
                page_content=formatted_content,
                metadata={
                    "chapter_number": chapter['number'],
                    "chapter_roman": chapter['roman'],
                    "chapter_title": chapter['title'],
                    "start_pos": chapter['start_pos'],
                    "end_pos": chapter['end_pos'],
                    "document_type": "chapter",
                    "source": "position_based"
                }
            )
            chapter_documents.append(doc)
            print(f"Processed Chapter {chapter['number']}: {chapter['title']}")
        
        vector_db = FAISS.from_documents(chapter_documents, self.embeddings)
        vector_db.save_local(db_path)
        print(f"Chapter database saved to {db_path}")
        return vector_db

# %% [markdown]
# ## Haupt QA-System-Klasse

# %%
class BookQASystem:

    
    def __init__(self, chunks_db: FAISS, chapters_db: FAISS, llm):
        self.chunks_db = chunks_db
        self.chapters_db = chapters_db
        self.llm = llm
        self.output_parser = StrOutputParser()
        
        self._setup_prompt_templates()
    
    def _setup_prompt_templates(self):

        
        self.general_prompt = ChatPromptTemplate.from_template("""
        You are a literary analysis expert. Use the provided book information to answer the question.
        If the information doesn't contain the answer, state that you don't know.
        
        Book Information:
        {context}
        
        Question: {question}
        
        Provide a clear and detailed answer:
        """)
        
        self.chapter_prompt = ChatPromptTemplate.from_template("""
        As a chapter analysis specialist, use the following chapter information to answer the question.
        
        Chapter Content:
        {context}
        
        Question about the chapter: {question}
        
        Provide a detailed explanation of events, characters, and key developments:
        """)
        
        self.summary_prompt = ChatPromptTemplate.from_template("""
        Create a summary based on the following book content:
        
        {context}
        
        Question: {question}
        
        Provide a concise and informative summary:
        """)
        
        self.character_prompt = ChatPromptTemplate.from_template("""
        Analyze character information from the book:
        
        {context}
        
        Character Question: {question}
        
        
        """) # Provide detailed character analysis:
    
    def _classify_question_type(self, question: str) -> str:

        question_lower = question.lower()
        
        if any(keyword in question_lower for keyword in ['chapter', 'kapital']):
            return "chapter"
        elif any(keyword in question_lower for keyword in ['summarize', 'summary', 'overview']):
            return "summary"
        elif any(keyword in question_lower for keyword in ['character', 'who is', 'person']):
            return "character"
        else:
            return "general"
    
    def _extract_chapter_number(self, question: str) -> Optional[int]:

        roman_match = re.search(r'\b([IVXLCDM]+)\b', question.upper())
        if roman_match:
            roman_num = roman_match.group(1)
            roman_map = ChapterExtractor.ROMAN_NUMERAL_MAP
            return roman_map.get(roman_num, 1)
        return None
    
    def _search_chapters(self, question: str, chapter_number: Optional[int] = None) -> List[Document]:

        if chapter_number:
            return self.chapters_db.similarity_search(
                question, k=3, filter={"chapter_number": chapter_number}
            )
        else:
            return self.chapters_db.similarity_search(question, k=5)
    
    def _search_chunks(self, question: str) -> List[Document]:

        return self.chunks_db.similarity_search(question, k=8)
    
    def _format_context(self, documents: List[Document]) -> str:

        context_parts = []
        for i, doc in enumerate(documents, 1):
            source_info = ""
            if 'chapter_number' in doc.metadata:
                source_info = f" [Chapter {doc.metadata['chapter_number']}]"
            elif 'page' in doc.metadata:
                source_info = f" [Page {doc.metadata['page']}]"
            
            context_parts.append(f"Excerpt {i}{source_info}:\n{doc.page_content}\n")
        
        return "\n".join(context_parts)
    
    def answer_question(self, question: str) -> str:

        print(f"Processing question: {question}")
        
        question_type = self._classify_question_type(question)
        print(f"Detected question type: {question_type}")
        
        if question_type == "chapter":
            chapter_num = self._extract_chapter_number(question)
            print(f"Searching in Chapter {chapter_num if chapter_num else 'all chapters'}")
            docs = self._search_chapters(question, chapter_num)
            context = self._format_context(docs)
            chain = self.chapter_prompt | self.llm | self.output_parser
            
        elif question_type == "summary":
            print("Gathering content for summary...")
            docs = self._search_chunks(question)
            context = self._format_context(docs)
            chain = self.summary_prompt | self.llm | self.output_parser
            
        elif question_type == "character":
            print("Searching for character information...")
            docs = self._search_chunks(question)
            context = self._format_context(docs)
            chain = self.character_prompt | self.llm | self.output_parser
            
        else:  # general
            print("Searching for general information...")
            docs = self._search_chunks(question)
            context = self._format_context(docs)
            chain = self.general_prompt | self.llm | self.output_parser
        
        return chain.invoke({"context": context, "question": question})

# %% [markdown]
# ## Systeminitialisierungsfunktion

# %%
def initialize_system():

    print("Initializing Book QA System...")
    
    # Initialisieren Sie Einbettungen und Vektorspeicher
    embeddings = HuggingFaceEmbeddings(model_name=EMBEDDINGS_MODEL_NAME)
    store_manager = VectorStoreManager(embeddings)
    
    # DATENBANK-LADUNG/ERSTELLUNG 
    chunks_db = store_manager.create_or_load_chunk_database(PDF_FILE, CHUNKS_DB_DIR)
    chapters_db = store_manager.create_or_load_chapter_database(PDF_FILE, CHAPTERS_DB_DIR)
    
    # LLM-Initialisieren
    llm = ChatOllama(model="llama3.2", temperature=0.2)
    
    # QA-SYSTEM-ERSTELLUNG 
    qa_system = BookQASystem(chunks_db, chapters_db, llm)
    print("QA System initialization complete!")
    return qa_system

# %% [markdown]
# ## Systemtest-funktion

# %%
def run_system_tests(qa_system: BookQASystem):

    test_questions = [

        "Who is the author of the book?",
        "How does the relationship between Heidi and her grandfather develop?",
        "What are the names of the goats in the story?",
        
        "Summarize the events of Chapter II",
        "What happened in CHAPTER III?",
        
        "Who is Peter?",
        "What places does Heidi visit in the story?",
        "Describe the main characters",

    ]
    
    print("Running System Tests")

    
    for i, question in enumerate(test_questions, 1):
        print(f"\nTest {i}: {question}")
        try:
            answer = qa_system.answer_question(question)
            print(f"Answer: {answer}")
            print("-" * 50)
        except Exception as e:
            print(f"Error processing question: {e}")
            print("-" * 50)

# %% [markdown]
# ## Hauptfunction

# %%
def main():

    try:
        qa_system = initialize_system()
        
        print("\nStarting system validation tests...")
        run_system_tests(qa_system)
           
    except Exception as e:
        print(f"System initialization failed: {e}")
        return 1
    
    return 0

if __name__ == "__main__":
    exit(main())
# Out:
# Initializing Book QA System...
# Creating new chunk database...
# Loaded 151 pages from Heidi.pdf
# Cleaned 151 documents
# Created 780 text chunks
# Chunk database saved to heidi_faiss_chunks
# Creating new chapter database...
# Loaded 151 pages from Heidi.pdf
# Extracting chapters from text...
# Found CHAPTER I. UP THE MOUNTAIN TO ALM-UNCLE at position 2804
# Found CHAPTER II. AT HOME WITH GRANDFATHER at position 30202
# Found CHAPTER III. OUT WITH THE GOATS at position 45694
# Found CHAPTER IV. THE VISIT TO GRANDMOTHER at position 72320
# Found CHAPTER V. TWO VISITS AND WHAT CAME OF THEM at position 99691
# Found CHAPTER VI. A NEW CHAPTER ABOUT NEW THINGS at position 120494
# Found CHAPTER VII. FRAULEIN ROTTENMEIER SPENDS AN UNCOMFORTABLE DAY at position 135844
# Found CHAPTER VIII. THERE IS GREAT COMMOTION IN THE LARGE HOUSE at position 162836
# Found CHAPTER IX. HERR SESEMANN HEARS OF THINGS WHICH ARE NEW TO HIM at position 183424
# Found CHAPTER X. ANOTHER GRANDMOTHER at position 194688
# Found CHAPTER XI. HEIDI GAINS IN ONE WAY AND LOSES IN ANOTHER at position 213047
# Found CHAPTER XII. A GHOST IN THE HOUSE at position 222489
# Found CHAPTER XIII. A SUMMER EVENING ON THE MOUNTAIN at position 243992
# Found CHAPTER XIV. SUNDAY BELLS at position 275764
# Found CHAPTER XV. PREPARATIONS FOR A JOURNEY at position 300685
# Found CHAPTER XVI. A VISITOR at position 313820
# Found CHAPTER XVII. A COMPENSATION at position 330992
# Found CHAPTER XVIII. WINTER IN DORFLI at position 347096
# Found CHAPTER XIX. THE WINTER CONTINUES at position 368381
# Found CHAPTER XX. NEWS FROM DISTANT FRIENDS at position 381985
# Found CHAPTER XXI. HOW LIFE WENT ON AT GRANDFATHER'S at position 413139
# Found CHAPTER XXII. SOMETHING UNEXPECTED HAPPENS at position 429642
# Found CHAPTER XXIII. "GOOD-BYE TILL WE MEET AGAIN" at position 458166
# Successfully extracted 23 chapters
# Processed Chapter 1: CHAPTER I. UP THE MOUNTAIN TO ALM-UNCLE
# Processed Chapter 2: CHAPTER II. AT HOME WITH GRANDFATHER
# Processed Chapter 3: CHAPTER III. OUT WITH THE GOATS
# Processed Chapter 4: CHAPTER IV. THE VISIT TO GRANDMOTHER
# Processed Chapter 5: CHAPTER V. TWO VISITS AND WHAT CAME OF THEM
# Processed Chapter 6: CHAPTER VI. A NEW CHAPTER ABOUT NEW THINGS
# Processed Chapter 7: CHAPTER VII. FRAULEIN ROTTENMEIER SPENDS AN UNCOMFORTABLE DAY
# Processed Chapter 8: CHAPTER VIII. THERE IS GREAT COMMOTION IN THE LARGE HOUSE
# Processed Chapter 9: CHAPTER IX. HERR SESEMANN HEARS OF THINGS WHICH ARE NEW TO HIM
# Processed Chapter 10: CHAPTER X. ANOTHER GRANDMOTHER
# Processed Chapter 11: CHAPTER XI. HEIDI GAINS IN ONE WAY AND LOSES IN ANOTHER
# Processed Chapter 12: CHAPTER XII. A GHOST IN THE HOUSE
# Processed Chapter 13: CHAPTER XIII. A SUMMER EVENING ON THE MOUNTAIN
# Processed Chapter 14: CHAPTER XIV. SUNDAY BELLS
# Processed Chapter 15: CHAPTER XV. PREPARATIONS FOR A JOURNEY
# Processed Chapter 16: CHAPTER XVI. A VISITOR
# Processed Chapter 17: CHAPTER XVII. A COMPENSATION
# Processed Chapter 18: CHAPTER XVIII. WINTER IN DORFLI
# Processed Chapter 19: CHAPTER XIX. THE WINTER CONTINUES
# Processed Chapter 20: CHAPTER XX. NEWS FROM DISTANT FRIENDS
# Processed Chapter 21: CHAPTER XXI. HOW LIFE WENT ON AT GRANDFATHER'S
# Processed Chapter 22: CHAPTER XXII. SOMETHING UNEXPECTED HAPPENS
# Processed Chapter 23: CHAPTER XXIII. "GOOD-BYE TILL WE MEET AGAIN"
# Chapter database saved to heidi_faiss_chapters
# QA System initialization complete!
#
# Starting system validation tests...
#
# ============================================================
# Running System Tests
# ============================================================
#
# Test 1: Who is the author of the book?
# Processing question: Who is the author of the book?
# Detected question type: character
# Searching for character information...
# Answer: The character information from the excerpts provided does not directly mention the author's name. However, based on the context and the list of works mentioned in Excerpt 4 (Page 1), it appears that the author is Johanna Spyri.
#
# Excerpt 4 lists several of her notable works, including "Heidi," which is the book being discussed in the excerpts. The mention of other works such as "Am Sonntag" and "Gritli's Kinder" further confirms that the author is indeed Johanna Spyri.
#
# Therefore, the answer to the character question is: The author of the book is Johanna Spyri.
# --------------------------------------------------
#
# Test 2: How does the relationship between Heidi and her grandfather develop?
# Processing question: How does the relationship between Heidi and her grandfather develop?
# Detected question type: general
# Searching for general information...
# Answer: The relationship between Heidi and her grandfather is a central theme in the novel. Initially, their bond is built on trust and affection, as evident from Excerpt 1. The child, Heidi, clings to the old man and looks up at him with confidence, while he responds with kindness and reassurance. When they decide to help Heidi deal with the rattling noise, her grandfather promises to take action, which fills her with joy.
#
# As the story progresses, their relationship deepens, and Heidi comes to rely on her grandfather for emotional support and companionship. In Excerpt 2, it is clear that Heidi has grown accustomed to having her grandfather around and enjoys his company. She takes pride in helping him with household chores and feels a sense of satisfaction when he praises her efforts.
#
# The grandfather's love and care for Heidi are evident in the way he encourages her to explore the outdoors and engage in activities she enjoys, such as playing with the dolls and sewing clothes for them. In Excerpt 7, it is mentioned that the grandmother had disappeared inside her room, but Fraulein Rottenmeier was not present either, implying that Heidi's grandfather was spending quality time with her.
#
# Moreover, the grandfather's relationship with Heidi helps him cope with his own emotional pain and loneliness. As revealed in Excerpt 8, he had been living alone with Ursula, who was deaf and cold, and Heidi's presence brings warmth and joy to his life. The grandmother's intervention in their interactions also suggests that she recognizes the importance of this bond between Heidi and her grandfather.
#
# Throughout the novel, it becomes apparent that the grandfather is not only a caregiver but also a source of comfort, love, and support for Heidi. He provides her with a sense of security and stability, which allows her to thrive and grow. The relationship between Heidi and her grandfather serves as a foundation for her development and happiness, and their bond remains strong throughout the story.
#
# In summary, the relationship between Heidi and her grandfather develops from one of trust and affection to a deep and nurturing bond that provides emotional support, companionship, and a sense of belonging.
# --------------------------------------------------
#
# Test 3: What are the names of the goats in the story?
# Processing question: What are the names of the goats in the story?
# Detected question type: general
# Searching for general information...
# Answer: The names of the goats mentioned in the story are:
#
# 1. The great Turk (a male goat with big horns)
# 2. Little Swan (a white female goat)
# 3. Little Bear (a brown female goat)
#
# These names are mentioned in Excerpts 4, 6, and 7.
# --------------------------------------------------
#
# Test 4: Summarize the events of Chapter II
# Processing question: Summarize the events of Chapter II
# Detected question type: chapter
# Searching in Chapter 2
# Answer: Chapter II of the novel "Heidi" by Johanna Spyri revolves around Heidi's first day at her grandfather's hut in the mountains. The chapter begins with Heidi returning to her grandfather's hut after her long journey from the city. She finds her grandfather sitting on his bench, staring at the ground without uttering a word.
#
# Upon entering the hut, Heidi discovers that it is small and simple, but cozy and warm. She sees her grandfather's bed, a table, a chair, and a hearth with a kettle hanging above it. The room also has a cupboard where her grandfather stores his clothes, food, and other essentials.
#
# Heidi is delighted to be in the hut and begins exploring every nook and cranny. She climbs up a short ladder to reach the hayloft, where she finds a large heap of fresh-smelling hay. Her grandfather helps her make a bed with a coarse piece of fabric that he brings from the cupboard.
#
# As they work on making the bed, Heidi's hunger returns, and her grandfather suggests having something to eat. They sit down at the table, and Heidi is delighted to find that her grandfather has prepared a simple but delicious meal consisting of bread, cheese, milk, and butter.
#
# After eating, Heidi watches as her grandfather fixes up the goat shed and creates a new three-legged stool for himself. She is amazed by his ingenuity and skill in making something from scratch.
#
# As the evening approaches, Heidi's excitement grows, and she dances around the old fir trees, enjoying the sound of the wind rustling through their branches. Her grandfather watches her with a smile, happy to see her so carefree and joyful.
#
# Finally, the goats return, and Heidi is overjoyed to see them again. She learns that the white goat is named Little Swan, and the brown one is named Little Bear. The grandfather tells her that she can keep them as pets, and they will stay with her at the hut.
#
# As the night falls, Heidi eats a final supper and then goes to bed, feeling content and happy. Her grandfather also retires to his bed, but not before checking on her to make sure she is safe and sound.
#
# Throughout the chapter, key developments include:
#
# * Heidi's arrival at her grandfather's hut and her initial exploration of the space
# * The making of the bed and the simple meal shared between Heidi and her grandfather
# * The creation of a new three-legged stool for the grandfather
# * The reunion with the goats, Little Swan and Little Bear
# * Heidi's joy and excitement as she settles into her new life at the hut
#
# Characters introduced in this chapter include:
#
# * Heidi: The protagonist of the story, who returns to her grandfather's hut after her long journey from the city.
# * Grandfather: Heidi's kind and skilled caretaker, who welcomes her back with open arms.
#
# Key themes explored in this chapter include:
#
# * The importance of simplicity and coziness in a home
# * The joy of exploration and discovery
# * The value of hard work and ingenuity
# * The bond between humans and animals
# --------------------------------------------------
#
# Test 5: What happened in CHAPTER III?
# Processing question: What happened in CHAPTER III?
# Detected question type: chapter
# Searching in Chapter 3
# Answer: In Chapter 3, Heidi and Peter spend the day climbing up to their mountain home with the goats. They have a wonderful time exploring the mountains, playing with the animals, and enjoying the beautiful scenery. Along the way, they see a great bird's nest on fire, which is actually just a natural phenomenon caused by the sun setting behind the mountains.
#
# As they climb higher, Heidi becomes more and more excited about the beauty of the mountains and the colors that appear as the sun sets. She describes the scene to her grandfather when she returns home, and he explains that it's just the sun saying goodnight to the mountains before it disappears for the day.
#
# The chapter also shows Heidi's kindness and compassion towards Snowflake, one of the goats, who is initially nervous around Peter but warms up to him after Heidi intervenes on his behalf. Heidi promises to visit Snowflake again the next day and to bring her some treats.
#
# Throughout the chapter, Heidi's curiosity and love for nature are on full display as she explores the mountains and learns about the world around her. Her grandfather is also depicted as a wise and kind figure who shares stories and explanations with Heidi about the natural world.
#
# The chapter ends with Heidi going to bed, dreaming of the beautiful mountains and the adventures she had with Peter and the goats. The tone of the chapter is peaceful and idyllic, capturing the sense of wonder and joy that Heidi feels as she explores the natural world.
# --------------------------------------------------
#
# Test 6: Who is Peter?
# Processing question: Who is Peter?
# Detected question type: character
# Searching for character information...
# Answer: Based on the provided excerpts, we can analyze Peter's character as follows:
#
# 1. **Honesty**: Peter is a truthful and open individual. He confesses to his mistakes and wrongdoing, such as losing the paper (Excerpt 1). This shows that he values honesty and is willing to take responsibility for his actions.
# 2. **Respect for authority**: Peter has great respect for his uncle and grandmother. He obeys their instructions and follows their advice, demonstrating a strong sense of obedience and respect for those in positions of authority (Excerpts 2-3).
# 3. **Curiosity and love for learning**: Peter is curious and loves to learn new things. He enjoys playing with the goats and listening to his grandmother's stories, showing that he values knowledge and experiences (Excerpt 3).
# 4. **Bravery and determination**: When faced with challenges or difficulties, Peter shows bravery and determination. He hurries back up the mountain despite feeling anxious and hurt, demonstrating his willingness to overcome obstacles (Excerpt 2).
# 5. **Faith and spirituality**: Peter seems to have a strong faith in God and believes that God sees and hears everything. He is comforted by this idea and finds peace when he receives news of good fortune (Excerpts 4-6).
# 6. **Emotional depth**: Peter experiences a range of emotions, from fear and anxiety to joy and happiness. His emotional responses are genuine and authentic, suggesting that he is a sensitive and empathetic individual.
# 7. **Desire for connection and relationships**: Peter values his relationships with others, particularly his grandmother and friends in Dorfli. He enjoys spending time with them and feels happy when they are around (Excerpts 3-4).
#
# Overall, Peter appears to be a kind, honest, and determined young boy who values honesty, respect, learning, faith, and relationships.
# --------------------------------------------------
#
# Test 7: What places does Heidi visit in the story?
# Processing question: What places does Heidi visit in the story?
# Detected question type: general
# Searching for general information...
# Answer: Based on the provided book excerpts, it appears that Heidi visits several places in the story. Here are some of the places mentioned:
#
# 1. The mountain: This is where Heidi lives with her grandfather after leaving her former home. She spends most of her time outdoors, exploring the mountain and its surroundings.
# 2. Frankfurt: This is where Heidi's parents lived before she left them to live with her grandfather on the mountain. Heidi visits Frankfurt occasionally, but it is not her primary residence.
# 3. The hut (or chalet): This is Heidi's home on the mountain, where she lives with her grandfather. It is a small, cozy dwelling surrounded by nature.
# 4. Dorfli: This is a village or town that Heidi visits during her stay in Frankfurt. She meets Fraulein Rottenmeier and Clara there, who are kind to her.
#
# It's worth noting that the story does not mention many other specific places that Heidi visits. The mountain and the hut seem to be the primary settings for most of the story, with occasional visits to Frankfurt and Dorfli.
# --------------------------------------------------
#
# Test 8: Describe the main characters
# Processing question: Describe the main characters
# Detected question type: character
# Searching for character information...
# Answer: Based on the provided excerpts, here are the descriptions of the main characters:
#
# 1. Heidi:
# 	* A young Swiss girl who is the protagonist of the story.
# 	* She is innocent, kind-hearted, and full of life.
# 	* She loves to play, explore, and help others.
# 	* She has a strong connection with nature and her surroundings.
# 	* She is also shown to be emotional and sensitive, as evident from her reaction to being scolded by the grandmother.
#
# 2. The Grandmother:
# 	* A kind and caring woman who takes care of Heidi.
# 	* She is shown to be patient, gentle, and loving towards Heidi.
# 	* She has a deep understanding of Heidi's nature and knows how to connect with her.
# 	* She is also depicted as someone who values education and wants to teach Heidi important life skills.
#
# 3. Clara:
# 	* A young girl who lives in the same house as Heidi.
# 	* She is shown to be spoiled, selfish, and entitled.
# 	* She is also depicted as someone who is struggling with her own emotions and desires.
# 	* Her relationship with Uncle is complex, and she seems to have a deep affection for him.
#
# 4. Uncle:
# 	* A kind and gentle man who lives in the house with Heidi and Clara.
# 	* He has a deep connection with nature and is shown to be at peace with himself.
# 	* He is also depicted as someone who values kindness, compassion, and understanding.
# 	* His relationship with Clara is complex, and he seems to have a deep affection for her.
#
# 5. The Captain:
# 	* A man who was Uncle's captain during the war.
# 	* He is shown to be wounded and in need of care.
# 	* Uncle's love and devotion towards him are evident, and he nurses him back to health.
#
# 6. Dete (or Barbel):
# 	* A young girl who lives in Domleschg and has a conversation with Heidi about her family history.
# 	* She is shown to be curious and interested in learning more about her past.
# 	* Her story serves as a contrast to Heidi's, highlighting the differences between their lives.
#
# These characters are central to the story, and their interactions and relationships with each other drive the plot forward.
# --------------------------------------------------
